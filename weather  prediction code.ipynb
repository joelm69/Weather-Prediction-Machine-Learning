# %%
import pandas as pd

weather = pd.read_csv("local_weather.csv", index_col= "DATE")
weather
# Out:
#                 STATION                                  NAME   ACMH   ACSH  \
# DATE
# 1975-03-13  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   80.0   90.0
# 1975-03-14  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   30.0   10.0
# 1975-03-15  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US  100.0  100.0
# 1975-03-16  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   30.0   30.0
# 1975-03-17  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US  100.0  100.0
# ...                 ...                                   ...    ...    ...
# 2023-12-27  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US    NaN    NaN
# 2023-12-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US    NaN    NaN
# 2023-12-29  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US    NaN    NaN
# 2023-12-30  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US    NaN    NaN
# 2023-12-31  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US    NaN    NaN
#
#              AWND  DAPR  FMTM  MDPR    PGTM  PRCP  ...  WSFG  WT01  WT02  \
# DATE                                               ...
# 1975-03-13    NaN   NaN   NaN   NaN   942.0  1.07  ...  38.0   1.0   NaN
# 1975-03-14    NaN   NaN   NaN   NaN  1806.0  0.00  ...  20.8   NaN   NaN
# 1975-03-15    NaN   NaN   NaN   NaN  2200.0  0.37  ...  34.4   NaN   NaN
# 1975-03-16    NaN   NaN   NaN   NaN   106.0  0.03  ...  23.0   NaN   NaN
# 1975-03-17    NaN   NaN   NaN   NaN  1512.0  0.00  ...  18.3   NaN   NaN
# ...           ...   ...   ...   ...     ...   ...  ...   ...   ...   ...
# 2023-12-27  10.51   NaN   NaN   NaN     NaN  0.06  ...   NaN   1.0   NaN
# 2023-12-28   3.80   NaN   NaN   NaN     NaN  0.00  ...   NaN   NaN   NaN
# 2023-12-29   8.28   NaN   NaN   NaN     NaN   NaN  ...   NaN   1.0   NaN
# 2023-12-30   6.71   NaN   NaN   NaN     NaN  0.21  ...   NaN   1.0   NaN
# 2023-12-31   3.13   NaN   NaN   NaN     NaN  0.00  ...   NaN   1.0   NaN
#
#             WT03  WT04  WT05  WT08  WT09  WT16  WT18
# DATE
# 1975-03-13   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# 1975-03-14   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1975-03-15   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# 1975-03-16   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# 1975-03-17   NaN   NaN   NaN   NaN   NaN   1.0   NaN
# ...          ...   ...   ...   ...   ...   ...   ...
# 2023-12-27   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-12-28   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-12-29   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-12-30   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2023-12-31   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [12012 rows x 32 columns]

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.823427
# ACSH       0.823427
# AWND       0.271146
# DAPR       0.999334
# FMTM       0.817682
# MDPR       0.999334
# PGTM       0.470030
# PRCP       0.023643
# SNOW       0.514652
# SNWD       0.504246
# TMAX       0.000916
# TMIN       0.001166
# TSUN       0.904179
# WDF1       0.823427
# WDF2       0.271062
# WDF5       0.278388
# WDFG       0.823427
# WSF1       0.823427
# WSF2       0.270979
# WSF5       0.278388
# WSFG       0.823427
# WT01       0.758825
# WT02       0.979520
# WT03       0.992674
# WT04       0.999833
# WT05       0.999584
# WT08       0.856227
# WT09       0.999917
# WT16       0.959374
# WT18       0.999917
# dtype: float64

# %%
core_weather = weather[["PRCP", "SNOW", "SNWD", "TMAX", "TMIN"]].copy()
core_weather.columns = ["precip", "snow", "snow_depth", "temp_max", "temp_min"]
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1975-03-13    1.07   0.0         0.0      53.0      40.0
# 1975-03-14    0.00   0.0         0.0      56.0      42.0
# 1975-03-15    0.37   0.0         0.0      55.0      48.0
# 1975-03-16    0.03   0.0         0.0      56.0      47.0
# 1975-03-17    0.00   0.0         0.0      60.0      47.0
# ...            ...   ...         ...       ...       ...
# 2023-12-27    0.06   NaN         NaN      59.0      45.0
# 2023-12-28    0.00   NaN         NaN      66.0      54.0
# 2023-12-29     NaN   NaN         NaN      63.0      55.0
# 2023-12-30    0.21   NaN         NaN      60.0      50.0
# 2023-12-31    0.00   NaN         NaN      57.0      46.0
#
# [12012 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/core_weather.shape[0]
# Out:
# precip        0.023643
# snow          0.514652
# snow_depth    0.504246
# temp_max      0.000916
# temp_min      0.001166
# dtype: float64

# %%
core_weather["snow"].value_counts()
# Out:
# 0.0    5829
# 1.0       1
# Name: snow, dtype: int64

# %%
del core_weather["snow"]

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 0.0    5955
# Name: snow_depth, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-12     NaN      63.0      55.0
# 1983-11-13     NaN      60.0      50.0
# ...            ...       ...       ...
# 2016-05-08     NaN      67.0      56.0
# 2017-10-28     NaN      68.0      50.0
# 2023-03-29     NaN      52.0      43.0
# 2023-12-06     NaN      61.0      47.0
# 2023-12-29     NaN      63.0      55.0
#
# [284 rows x 3 columns]

# %%
core_weather.loc["1983-10-29":"2023-12-29",:]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1983-10-29     NaN      67.0      57.0
# 1983-10-30     NaN      70.0      63.0
# 1983-10-31     NaN      69.0      61.0
# 1983-11-01    0.26      69.0      60.0
# 1983-11-02    0.06      68.0      56.0
# ...            ...       ...       ...
# 2023-12-25    0.00      57.0      40.0
# 2023-12-26    0.00      58.0      43.0
# 2023-12-27    0.06      59.0      45.0
# 2023-12-28    0.00      66.0      54.0
# 2023-12-29     NaN      63.0      55.0
#
# [9769 rows x 3 columns]

# %%
core_weather["precip"].value_counts()
# Out:
# 0.00    9715
# 0.01     336
# 0.02     133
# 0.03      74
# 0.05      68
#         ...
# 1.90       1
# 1.98       1
# 2.01       1
# 1.25       1
# 1.28       1
# Name: precip, Length: 160, dtype: int64

# %%
core_weather["precip"].fillna(0)
# Out:
# DATE
# 1975-03-13    1.07
# 1975-03-14    0.00
# 1975-03-15    0.37
# 1975-03-16    0.03
# 1975-03-17    0.00
#               ...
# 2023-12-27    0.06
# 2023-12-28    0.00
# 2023-12-29    0.00
# 2023-12-30    0.21
# 2023-12-31    0.00
# Name: precip, Length: 12012, dtype: float64

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 2004-11-20     NaN       NaN       NaN
# 2011-12-21     0.0      61.0       NaN
# 2011-12-22     0.0      62.0       NaN
# 2011-12-23     0.0      56.0       NaN
# 2011-12-24     0.0      55.0       NaN
# 2011-12-25     0.0      54.0       NaN
# 2013-06-16     0.0       NaN       NaN
# 2020-08-29     0.0       NaN       NaN
# 2020-09-08     0.0       NaN       NaN
# 2020-09-09     0.0       NaN       NaN
# 2022-10-08     0.0       NaN       NaN
# 2022-10-09     0.0       NaN       NaN
# 2022-10-10     0.0      69.0       NaN
# 2022-10-11     0.0      66.0       NaN

# %%
core_weather = core_weather.fillna(method="ffill")
core_weather.apply(pd.isnull).sum()
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index
# Out:
# Index(['1975-03-13', '1975-03-14', '1975-03-15', '1975-03-16', '1975-03-17',
#        '1975-03-18', '1975-03-19', '1975-03-20', '1975-03-21', '1975-03-22',
#        ...
#        '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25', '2023-12-26',
#        '2023-12-27', '2023-12-28', '2023-12-29', '2023-12-30', '2023-12-31'],
#       dtype='object', name='DATE', length=12012)

# %%
core_weather.index = pd.to_datetime(core_weather.index)
core_weather.index
# Out:
# DatetimeIndex(['1975-03-13', '1975-03-14', '1975-03-15', '1975-03-16',
#                '1975-03-17', '1975-03-18', '1975-03-19', '1975-03-20',
#                '1975-03-21', '1975-03-22',
#                ...
#                '2023-12-22', '2023-12-23', '2023-12-24', '2023-12-25',
#                '2023-12-26', '2023-12-27', '2023-12-28', '2023-12-29',
#                '2023-12-30', '2023-12-31'],
#               dtype='datetime64[ns]', name='DATE', length=12012, freq=None)

# %%
core_weather.index.month
# Out:
# Int64Index([ 3,  3,  3,  3,  3,  3,  3,  3,  3,  3,
#             ...
#             12, 12, 12, 12, 12, 12, 12, 12, 12, 12],
#            dtype='int64', name='DATE', length=12012)

# %%
core_weather.index.year
# Out:
# Int64Index([1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975,
#             ...
#             2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
#            dtype='int64', name='DATE', length=12012)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
import matplotlib
core_weather[["temp_max", "temp_min"]].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.index.year.value_counts().sort_index()
# Out:
# 1975    294
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1983    184
# 1984    366
# 1985    365
# 1986    212
# 2000    365
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    365
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# Name: DATE, dtype: int64

# %%
core_weather["precip"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather["temp_min"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather["temp_max"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1975    10.35
# 1976     8.64
# 1977    11.70
# 1978    22.57
# 1979    23.79
# 1980    13.58
# 1983    13.37
# 1984    16.03
# 1985     8.50
# 1986     0.00
# 2000    21.09
# 2001    22.85
# 2002    19.12
# 2003    11.37
# 2004    12.98
# 2005    27.37
# 2006    22.79
# 2007    12.79
# 2008    13.86
# 2009    14.57
# 2010    22.67
# 2011    16.06
# 2012    22.93
# 2013     4.89
# 2014    19.62
# 2015     8.58
# 2016    19.79
# 2017    23.34
# 2018    16.82
# 2019    20.00
# 2020     6.42
# 2021    20.82
# 2022    15.38
# 2023    21.62
# Name: precip, dtype: float64

# %%
core_weather["target"]= core_weather.shift(-1)["temp_max"]
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1975-03-13    1.07      53.0      40.0    56.0
# 1975-03-14    0.00      56.0      42.0    55.0
# 1975-03-15    0.37      55.0      48.0    56.0
# 1975-03-16    0.03      56.0      47.0    60.0
# 1975-03-17    0.00      60.0      47.0    62.0
# ...            ...       ...       ...     ...
# 2023-12-27    0.06      59.0      45.0    66.0
# 2023-12-28    0.00      66.0      54.0    63.0
# 2023-12-29    0.00      63.0      55.0    60.0
# 2023-12-30    0.21      60.0      50.0    57.0
# 2023-12-31    0.00      57.0      46.0     NaN
#
# [12012 rows x 4 columns]

# %%
core_weather = core_weather.iloc[:-1,:].copy()
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1975-03-13    1.07      53.0      40.0    56.0
# 1975-03-14    0.00      56.0      42.0    55.0
# 1975-03-15    0.37      55.0      48.0    56.0
# 1975-03-16    0.03      56.0      47.0    60.0
# 1975-03-17    0.00      60.0      47.0    62.0
# ...            ...       ...       ...     ...
# 2023-12-25    0.00      57.0      40.0    58.0
# 2023-12-26    0.00      58.0      43.0    59.0
# 2023-12-27    0.06      59.0      45.0    66.0
# 2023-12-28    0.00      66.0      54.0    63.0
# 2023-12-29    0.00      63.0      55.0    60.0
#
# [12010 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=.1)

# %%
predictors = ["precip", "temp_max", "temp_min"]

# %%
train= core_weather.loc[:"2020-12-31"]

# %%
test=  core_weather.loc[:"2023-12-29"]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions =reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 3.4549374938818183

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns=["actual","predictions"]
combined
# Out:
#             actual  predictions
# DATE
# 1975-03-13    56.0    52.488656
# 1975-03-14    55.0    57.630296
# 1975-03-15    56.0    57.040482
# 1975-03-16    60.0    58.423747
# 1975-03-17    62.0    61.352728
# ...            ...          ...
# 2023-12-25    58.0    57.996802
# 2023-12-26    59.0    59.231157
# 2023-12-27    66.0    60.143145
# 2023-12-28    63.0    66.849590
# 2023-12-29    60.0    64.882223
#
# [12010 rows x 2 columns]

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-2.4799668 ,  0.71364557,  0.17356983])

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
core_weather ["month_max"] = core_weather["temp_max"].rolling(30).mean()
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max
# DATE
# 1975-03-13    1.07      53.0      40.0    56.0        NaN
# 1975-03-14    0.00      56.0      42.0    55.0        NaN
# 1975-03-15    0.37      55.0      48.0    56.0        NaN
# 1975-03-16    0.03      56.0      47.0    60.0        NaN
# 1975-03-17    0.00      60.0      47.0    62.0        NaN
# ...            ...       ...       ...     ...        ...
# 2023-12-25    0.00      57.0      40.0    58.0  60.400000
# 2023-12-26    0.00      58.0      43.0    59.0  60.366667
# 2023-12-27    0.06      59.0      45.0    66.0  60.200000
# 2023-12-28    0.00      66.0      54.0    63.0  60.300000
# 2023-12-29    0.00      63.0      55.0    60.0  60.300000
#
# [12010 rows x 5 columns]

# %%
core_weather ["month_day_max"]=core_weather ["month_max"]/ core_weather["temp_max"]
core_weather ["max_min"]=core_weather ["temp_max"]/ core_weather["temp_min"]
predictors = ["precip", "temp_max", "temp_min", "month_day_max", "max_min"]

# %%
core_weather= core_weather.iloc[30:,:].copy()

# %% [markdown]
# error, combined = create_predictions(predictors, core_weather, reg)
# error

# %%
combined.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>
